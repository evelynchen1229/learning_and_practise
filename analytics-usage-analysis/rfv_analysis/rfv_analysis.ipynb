# %%
import pandas as pd
import openpyxl
from sklearn import preprocessing
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
rfv = pd.read_excel('rfv_analysis.xlsx',sheet_name='Sheet3')

# %%
sns.displot(rfv_analysis,x='rfv_score')

# %%
rfv_analysis[(rfv_analysis['total_active_days']==2) & (rfv_analysis['rfv_score']>4) & (rfv_analysis['rfv_score']< 4.5)]
# Out:
#                user_id  total_active_days  average_days_per_week  \
# 1340  5117356105018060                  2                      2
# 1875  5295436253855790                  2                      2
# 1966  5043654235727650                  2                      2
# 2002  5067006760033130                  2                      2
# 2133  5707521399263870                  2                      2
# 2160  4549794601738870                  2                      2
# 2215  5262907663748610                  2                      2
# 2360  7671852252839840                  2                      2
# 2581  5552026671495480                  2                      2
# 2703  5212980632094140                  2                      2
# 2716  7664281226922920                  2                      2
# 2758  4773579549415200                  2                      2
# 2852  5052429914870900                  2                      2
# ...

# %%
sns.displot(rfv_analysis,x='total_elapse_time_min', bins = 50)

# %%
rfv_analysis['total_elapse_time_min'].describe()
# Out:
# count    46509.000000
# mean        32.906040
# std         71.336337
# min          0.000000
# 25%          2.000000
# 50%         11.000000
# 75%         34.000000
# max       2157.000000
# Name: total_elapse_time_min, dtype: float64

# %%
sns.displot(rfv_analysis,x='total_active_days', bins = 50)

# %%
rfv_analysis['total_active_days'].describe()
# Out:
# count    46509.000000
# mean         2.582210
# std          2.824878
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         39.000000
# Name: total_active_days, dtype: float64

# %%
sns.displot(rfv_analysis,x='average_days_per_week', bins = 10)
rfv_analysis['average_days_per_week'].describe()
# Out:
# count    46509.000000
# mean         1.348191
# std          0.654578
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          7.000000
# Name: average_days_per_week, dtype: float64
